# %%
import pandas as pd
import random
import itertools

# Function to create unique synthetic data
def generate_unique_synthetic_data(base_texts, intent, num_samples):
    unique_data = list(itertools.islice(itertools.cycle(base_texts), num_samples))
    return [{"text": text, "intent": intent} for text in unique_data]

# Base texts for each specific intent tailored to a cosmetics and haircare brand
product_inquiry_availability_base = [
    "Is the new lipstick collection available?",
    "Is the hydrating serum still in stock?",
    "Do you have the anti-aging cream available?",
    "Can I purchase the new matte foundation online?",
    "Is the brightening mask available at your stores?",
    "When will the charcoal face wash be back in stock?",
    "When will the latest foundation be back in stock?",
    "Are the skincare products available for bulk purchases?",
    "Do you have the hair straighteners in stock?",
    "Can I pre-order the new moisturizer?",
    "Is the new matte lipstick shade 'Velvet Rouge' still available? It's sold out online.",
    "When will you be restocking the Radiant Glow highlighter palette? I need to get my hands on it!",
    "Are the limited edition holiday brush sets still in stores or were they an online exclusive?",
    "Do you know if the Porcelain shade of your foundation stick is being discontinued? I can't find it anymore.",
    "I'm looking for a specific shimmery eyeshadow single called 'Gilded' but can't locate it on your website.",
    "I've searched this everywhere and I couldn't find it. Is it still available in Romania?",
    "Can you help me find this cream? Thanks!",
    "no longer in stock",
    "I'd like to ask if the cream for normal and dry skin is becoming more expensive. I bought it from a site, and the tube is larger but at the same price. I'm worried it might not be original.",
    "I'm curious if the cream for normal and dry skin is increasingly costly. I got it from a website, and although the tube is bigger, the price remains the same. Could it be that it's not genuine?",
    "I wanted to ask if the price of the cream for normal and dry skin is rising. I purchased it from an online store, and the tube seems taller for the same price. I suspect it might not be authentic.",
    "Can you tell me if the cream for normal and dry skin is getting pricier? I ordered it from a site, and while the tube is larger, the price hasn't changed. I'm concerned it might be a counterfeit.",
    "I'm wondering if the cream for normal and dry skin is more expensive now. I bought it online, and the tube is higher but still at the same price. I'm worried it might not be the original product.",
    "Why don't you bring the Red shampoo in country? You only sell it abroad",
    "Is the Velvet Matte Liquid Lipstick in the shade Turkish Rose still being produced?",
    "Your website says the Pro Contour Palette is out of stock. When can I expect a restock?",
    "I can't seem to find the Featherlight Skin Tint anywhere! Has it been discontinued?",
    "Do you know if the holiday Glam Goddess Brush Set will be released again this year?",
    "Hi! Is this product still available?",
    "I looked everywhere for a moisturizer with a gel texture, but it was only available on two websites, both charging double the price.",
    "I searched extensively for a shampoo with a honey formula, yet I could only find it on two sites, and both had it priced at twice the usual rate.",
    "I tried to find a serum with a velvet finish all over the internet, but I only located it on two platforms, where it was listed at double the cost.",
    "I scoured the web for a cleanser with a mousse consistency, but it was only present on two websites, both offering it at double the normal price.",
    "I hunted for a foundation with a cream-to-powder formula everywhere online, and it was only available on two sites, each pricing it at double the standard amount.",
    "I looked everywhere for this product and I couldn’t find it! Can you tell me it’s still produced?",
    "I bought this product one year ago from France and I was really pleased with it. Now I’m living in Romania and I can’t find it anywhere. Can you please help me?",
    "Is it in MegaImage?",
    "Can I find it in Romania?",
    "Do you still produce the shade number 24?",
    "Can I still find the old version of this product?",
    "I want to know if this product will ever be available again.",
    "I couldn't find it in supermarkets.",
    "When will we be able to purchase it in Romania?",
    "When is it coming in Romania?",
    "I couldn't find it in Carrefour, I'm gonna look for it in other stores.",
    "Can it only be purchased online?",
    "In which stores can I find it?",
    "Which are the stores where I can't find the product?",
    "Do you sell it in pharmacies too?",
    "Can I find it in any pharmacy?",
    "Is it available in stores and in pharmacies too?",
    "When is the release date?",
    "Is it gonna be available in dm?",
    "Is it sold out?",
    "I searched the micellar water with milk texture.Why didn't there anywhere?I searched everywhere!",
    "When it's going to be back on stock?",
    "How can I be notified if it's back on stock?",
    "why don't you bring to the Romanian markets and oily hair shampoo?",
    "The best products you have are not marketed at all in the country.",
    "Are these the last products?",
    "Is this foundation still fucking available?",
    "Do you have this lipstick in stock, or is it out of stock again?",
    "I can't find this product on your site, is it available or not?",
    "Is the moisturizer back in stock yet? I'm tired of waiting.",
    "Are you ever going to restock this damn eyeshadow?",
    "When will you have more of this fucking product?",
    "Why is this always out of stock? Do you even restock?",
    "Is there any chance you'll get more of this soon? It's fucking annoying!",
    "Is this cruelty-free product available?",
    "When will you restock the vegan lipstick?",
    "Why is the eco-friendly packaging always out of stock?",
    "When can I buy the plastic-free skincare set again?",
    "Is the paraben-free moisturizer available or not?"
]

product_inquiry_ingredients_base = [
    "What are the ingredients of the new lipstick?",
    "What are the main ingredients in the revitalizing night cream?",
    "Does the hydrating serum contain hyaluronic acid?",
    "Are there any parabens in the anti-aging lotion?",
    "Can you provide the full ingredient list for the brightening mask?",
    "Is the face wash free from sulfates?",
    "Does the foundation contain any parabens?",
    "Are the skincare products vegan?",
    "Is the hair serum free from sulfates?",
    "Can you provide the ingredient list for the new moisturizer?"
    "What are the main ingredients in your Vitamin C serum? I'm trying to avoid specific chemicals.",
    "I have an almond allergy - do any of your products contain nut oils or derivatives?",
    "Are the mineral sunscreens you use nano or non-nano particles? I prefer non-nano for safety.",
    "Your Detox clay mask contains charcoal, right? Just want to double check before purchasing.",
    "I noticed your concealer has dimethicone listed - is this a new formulation change?",
    "Does is contain niacinamides?",
    "bakuchiol",
    "cerammide",
    "collagen",
    "glycerin",
    "glycolic acid",
    "hyaluronic acid",
    "keratin",
    "lactic acid",
    "retinol",
    "salicylic acid",
    "silicon",
    "squalane",
    "squalene",
    "algae",
    "aloe vera",
    "apricot",
    "argan oil",
    "blue tansy",
    "caffein",
    "calendula",
    "CBD",
    "charcoal",
    "cinnamon",
    "coconut",
    "manuka honey",
    "hibiscus",
    "essential oil",
    "ginseng",
    "honey",
    "jojoba",
    "lavender",
    "mushrooms",
    "olive oil",
    "peptides",
    "probiotics",
    "shea butter",
    "vitamin a",
    "vitamin c",
    "vitamin e",
    "does vitamin c increase skin glow?"
    "what does vitamin c do to your face",
    "vitamin c bightens face",
    "is 50 too late to start retinol?"
    "can i put retinol under my eyes?",
    "does hyaluronic acid raise blood pressure?"
    "what's better retinol or hyaluronic acid",
    "I have a nut allergy. Do any of your eyeshadow palettes contain nut-derived ingredients?",
    "If it has an alcohol distorted and perfume I will not buy",
    "What percentage of your skincare line is vegan and free of animal by-products?",
    "Your Detoxifying Clay Mask contains bentonite clay, right? Just want to confirm before purchasing.",
    "I'm trying to avoid alcohols in my skincare. Are any of your toners or mists alcohol-free?",
    "Does it contain perfume?",
    "Does it contain alcohol?",
    "Does it contain niacinamide?",
    "Does it contain AHA BHA?",
    "Does it contain ceramide?",
    "Does it contain peptides?",
    "Does it contain salicylic acid?",
    "Does it contain parabens?",
    "Will the perfume irritate my sensitive skin?",
    "Can I use it if I'm allergic to hyaluronic acid?",
    "Can I use it if I'm taking Roaccutane? Are the ingredients compatible with this treatment?",
    "Is it perfume free?",
    "Is it alcohol free?",
    "Vitamin C increase the sunscreens effects?",
    "Due to the presence of retinol, if I'm using it in the night, do I need to apply SPF in the morning?",
    "Do the ingredients irritate the skin?",
    "Is this product suitable for sensitive skin also?",
    "Is this product suitable for acne skin?",
    "Is it vegan?",
    "All the ingredients are vegan?",
    "So due to the ingredients it's supposed to be as good for the dried skin as it is for the normal skin. Right?",
    "Does it contain allergens?",
    "What the hell is in your new serum?",
    "Does this product contain any parabens?",
    "Is this shampoo sulfate-free or what?",
    "Can you provide a full ingredient list for this lotion?",
    "Are there any animal-derived ingredients in this product?",
    "Are these ingredients safe for sensitive skin, or is it all bullshit?",
    "Are any of these ingredients known to cause cancer?",
    "Does this product have any allergens? I can't risk it.",
    "What the fuck are the active ingredients in this?",
    "Is this cruelty-free product available?",
    "When will you restock the vegan lipstick?",
    "Why is the eco-friendly packaging always out of stock?",
    "When can I buy the plastic-free skincare set again?",
    "Is the paraben-free moisturizer available or not?"
]

product_inquiry_usage_instructions_base = [
    "How do I apply the new foundation?",
    "Can you provide usage instructions for the hair straighteners?",
    "How often should I use the face mask?",
    "Can the serum be used daily?",
    "How do I use the vitamin C serum?",
    "What's the best way to apply the night cream?",
    "Can I use this mask more than once a week?",
    "Should I apply the toner before or after moisturizing?",
    "Is this product suitable for daily use?",
    "What are the directions for using the new sunscreen?",
    "How should I apply and blend your cream contour palette? Looking for technique tips.",
    "What's the best way to remove your long-wear liquid lipsticks without drying out my lips?",
    "Should I use the illuminating primer before or after my makeup? Does it go under foundation?",
    "How many pumps of the Vitamin C serum do you recommend using for the full face?",
    "Do you have any tutorials on achieving the perfect cat-eye liner look with your gel pencil?",
    "What's the best way to apply your Radiant Glow Body Shimmer?♀️",
    "Should I use the Mattifying Face Primer before or after my foundation?",
    "Any tips for blending out the cream contour shades from your Pro Palette?",
    "Around how many pumps of serum would you recommend for the full face and neck?",
    "Can it be used in combination with vitamin C?",
    "Can it be used in combination with retinol?",
    "Is it a night routine product or a day one?",
    "Do I need to apply SPF in the morning if I'm putting this face cream on before I sleep?",
    "Can I introduce it in my everyday routine?",
    "Does is work as a second step in a double cleansing?",
    "Does it remove makeup too?",
    "Can I use it on the eye area too?",
    "Are you sure that it's suitable for the body and the face too? Isn't it going to be too harsh for the skin?",
    "Should I use a",
    "Should I use it if I'm going to do a chemical peeling the next day?",
    "Is it ok to use on an irritate skin (after a cosmetic treatment)?",
    "How should I introduce this product in my routine if I'm using retinol?",
    "Is it compatible with a niacinamide serum?",
    "Can I apply this aloe gel after I had a mechanical peeling?",
    "Do I need to wash the hair once or twice?",
    "How much time should I leave it to act on the skin?",
    "How much should I leave it on the hair?",
    "3 minutes is enough for it to action?",
    "Do I need to rinse with water after use?",
    "If I'm leave it longer on my hair, the color it's gonna be stronger?",
    "Can I apply the conditioner and the mask too?",
    "First I apply the serum then the cream?",
    "Mist after or before the cream?",
    "Can I use the mist on top of the makeup?",
    "Is this face cream friendly with makeup? Can I use it as a primer? I saw that it contains panthenol so it's supposed to hydrate the skin.",
    "How many times per week is it indicate to use?",
    "How the hell do I use this product?",
    "Can someone tell me how to apply this properly?",
    "Do I need to use this on dry or damp skin?",
    "Are there any specific steps to follow when using this mask?",
    "Can I use this daily, or will it screw up my skin?",
    "Is there a tutorial on how to use this properly?",
    "Should I apply this before or after my moisturizer?",
    "What’s the best way to use this, without fucking it up?",
    "How do I use this eco-friendly product?",
    "Can someone explain how to apply this vegan cream?",
    "Is this safe for daily use on sensitive skin?",
    "What are the instructions for using this cruelty-free serum?",
    "How should I apply this pollution-fighting face mask?"
]

product_inquiry_price_base = [
    "What is the price of the new lipstick?",
    "How much does the latest foundation cost?",
    "How much does the anti-aging serum cost?",
    "What's the price of the new moisturizer?",
    "Is there a discount on the face scrub?",
    "Can you tell me the price of the entire skincare set?",
    "How much is the shipping cost for this product?",
    "Are there any discounts available for the skincare products?",
    "What is the price range for the hair care products?",
    "Can you provide the price details for the new moisturizer?",
    "Hi, how much does the limited edition Smokey Eye palette retail for before taxes?",
    "What are the prices for the travel size versions of your best-selling mascaras?",
    "I'm looking at the Radiant Finishing powder online but the price seems high - is it sold individually or as a duo/set?",
    "Could you let me know the cost of your Charcoal Detox face mask? Not seeing it listed anywhere.",
    "Are the prix fixe brush sets discounted from the individual brush prices if purchased separately?",
    "What's the price point for your new High-Def Liquid Highlight? Couldn't find it listed."
    "Do you happen to know the cost of your top-selling mascara in the travel/mini size?"
    "The Body Butter seems expensive - is it sold individually or as part of a set?"
    "Could you let me know how much your cult-favorite Radiance Primer retails for?",
    "Price",
    "Price?",
    "Price?",
    "How much?",
    "How much does it cost?",
    "What's the cost of this product?",
    "When are the sales coming?",
    "Will it be reduced on Black Friday?",
    "Will it be reduced at the end of the month?",
    "How much is it going to be after the discount?",
    "Any discount?",
    "How can I receive a discount?",
    "How much does this product cost, for fuck's sake?",
    "Is this really worth $50? Seems like a rip-off.",
    "Why is this so damn expensive?",
    "Do you have any discounts for this item?",
    "Can you justify the price of this shit?",
    "What's the price on this? Can't find it anywhere!",
    "Are there any hidden costs with this?",
    "How the hell is this so pricey?",
    "Do you offer price matching for this product?",
    "How much does this vegan product cost?",
    "Why is this cruelty-free makeup so expensive?",
    "Is this plastic-free packaging worth the price?",
    "Do you offer any discounts on eco-friendly products?",
    "What is the price of this microplastic-free scrub?"
]

product_inquiry_recommendations_base = [
    "I'm looking for a long-wearing foundation for combination skin. What would you recommend?",
    "Can you suggest a good hydrating serum to use under makeup? My skin has been so dry lately.",
    "I need a volumizing mascara that doesn't clump or flake. Any recommendations from your line? ",
    "What do you recommend for dry skin?",
    "Can you suggest a good moisturizer for oily skin?",
    "What's the best product for reducing wrinkles?",
    "Do you have any recommendations for a daily sunscreen?",
    "Which cleanser would you suggest for sensitive skin?",
    "What's your best highlighter for a blinding glow? I have medium/tan skin.",
    "I recommend that you encapsulate the serum with pure vitamin C as it oxidizes very quickly.",
    "I'm interested in trying your brand's brow products. Which one would you suggest for full, feathered brows? ",
    "Do you have any color correcting products you'd recommend for my dark circles and redness? ",
    "I'm looking to try a lightweight tinted moisturizer instead of foundation. What's a good one for light coverage?",
    "What lip product would you suggest for a long-lasting, comfortable matte lip color? ",
    "Could you recommend a good face sunscreen that wears well under makeup? I need SPF 30+. ",
    "I have acne-prone skin and am interested in your skincare line. Where should I start? What products do you suggest?",
    "I'm in the market for a new eyeshadow palette. Which one from your line would you recommend for neutral, everyday looks?",
    "Can you suggest a good blush formula that doesn't accentuate texture or look cakey? I have dry, mature skin.",
    "I need a setting powder that doesn't look dry or cakey under my eyes. What would you recommend for brightening too?",
    "What is your best liquid eyeliner pen for a precise winged liner look? I need something super black and smudge-proof.",
    "I'm hoping to find a good primer that smooths out pores and texture. Any recommendations for your gripping or filling primers?",
    "Do you have any cream or liquid bronzer/contour products you'd recommend for achieving a natural, subtle contour?",
    "I'm looking to try one of your glow/radiance boosting primers or setting sprays. Which one would you suggest?",
    "What would be your recommended skincare routine for someone with combination, acne-prone skin in their 30s?",
    "I want to try one of your dewy, natural finish foundations. Which one has good coverage but still looks like skin?",
    "Can you recommend a good matte bronzer shade for light-medium warm olive skin tones from your line?",
    "What lip liner would you suggest for preventing feathering and making lipstick last longer?",
    "I'm searching for an under-eye corrector to brighten and color correct dark circles. Any recommendations?",
    "Your brow products look amazing! Which one would you suggest for someone wanting feathery, laminated brows?",
    "I need a good oil-control product to mattify throughout the day. Do you have any mattifying sprays or blotting products?",
    "What lipstick formula would you recommend for a comfortable, long wearing red shade?",
    "I want you to recommmend a day and night cream for +50,thank you!",
    "Can you recommend a fucking good moisturizer for dry skin?",
    "I need a serum that actually works, any suggestions?",
    "What's the best product you have for acne?",
    "Can you suggest something for sensitive skin that won’t cause breakouts?",
    "Are there any products that help with dark spots?",
    "I need a recommendation for an anti-aging cream that’s worth the damn money.",
    "What’s the best product for reducing wrinkles?",
    "Do you have a good recommendation for a vegan foundation?",
    "What should I use for extremely dry, flaky skin?",
    "Can you recommend a good vegan moisturizer?",
    "I need a cruelty-free serum that works, any suggestions?",
    "What eco-friendly product do you recommend for oily skin?",
    "What's the best product for acne that doesn't contain microplastics?",
    "Can you suggest a plastic-free option for sensitive skin?"
]

customer_support_order_status_base = [
    "Can you provide an update on my order status?",
    "My order hasn't arrived yet, can you check?",
    "When will my order be delivered?",
    "How do I track my order status?",
    "Is my order still on its way?",
    "I want to buy this",
    "Can you update me on my order status?",
    "Has my order shipped yet?",
    "When will my order be delivered?",
    "Is there a way to track my order?",
    "Why is my order taking so long?",
    "i want a shampoo and a mask",
    "i will buy the serum",
    "I placed an order a week ago but haven't received any shipping notification yet. Can you check the status?",
    "My order confirmation shows delivered but I haven't received my package yet. What do I do?",
    "It's been 10 days and my order still shows processing with no movement. When will it ship out?",
    "I got an order delivery exception notification but no other details. Is my order lost or delayed?",
    "I received someone else's order by mistake instead of my own. This needs to be resolved urgently!",
    "Hi, I placed an order last week but haven't received any shipping updates yet. Can you check?",
    "My order status shows delivered but I haven't actually received my package. What gives?",
    "It's been 10 days and my order is still processing with no movement. When will it ship?",
    "I got a delivery exception notice for my order but no other details. Is it lost or delayed?",
    "How can I verify my order status?",
    "Where I can see the status of my order?",
    "I ordered it yesterday. Will it arrive on Monday?",
    "How many business days does it take for the package to arrive?",
    "Where can I see if my package pass the customs?",
    "Where the fuck is my order?",
    "My order is delayed, what the hell is going on?",
    "Unde dracu este comanda mea?",
    "I haven’t received any updates on my order, this is bullshit.",
    "Can you check the status of my order? It's been weeks!",
    "Why the fuck hasn’t my order shipped yet?",
    "Can someone tell me if my order is coming or not?",
    "This delay is unacceptable, what the hell?",
    "I need an update on my order status immediately!",
    "Why is my order still processing? This is ridiculous!",
    "Where is my order for the cruelty-free products?",
    "My order for the vegan makeup is delayed, what's going on?",
    "I haven’t received any updates on my order for the plastic-free set.",
    "Why hasn’t my order for the paraben-free items shipped yet?"
]

customer_support_shipping_issues_base = [
    "There was an issue with the shipping address, can you help?",
    "My order was shipped to the wrong address, what should I do?",
    "Can you assist with the shipping delay?",
    "The tracking information for my order is incorrect.",
    "I need to change the shipping address for my order.",
    "My order shipment arrived damaged with products spilling out of the boxes. Who do I contact?",
    "I received the wrong item than what I had ordered. The product was also used! I need a refund.",
    "My order was shipped to the wrong address although I had entered the right one. How to re-route it?",
    "The shipping carrier has had my package for 2 weeks without any update. What is going on here?",
    "I paid extra for express shipping but my order took just as long as regular ground shipping!",
    "My shipment arrived with products leaking out of the damaged boxes. Who do I contact?",
    "I received someone else's order instead of my own items! This needs to be resolved.",
    "My order was shipped to the incorrect address even though I double checked it. Can it be rerouted?",
    "The shipping carrier has had my package for over 2 weeks now with zero updates!",
    "waiting for my order",
    "waiting to receive my order",
    "waiting to get my order",
    "My package hasn't arrived yet.",
    "The delivery address is incorrect.",
    "I received a damaged product.",
    "My order was shipped to the wrong address.",
    "How can I change my shipping details?",
    "My package arrived damaged, what the hell?",
    "Why is the shipping taking so fucking long?",
    "I paid for express shipping, why is it late?",
    "The tracking info hasn’t updated in days, what the fuck?",
    "Can you resend my order? It never arrived!",
    "This is the second time my package has been lost, what the hell?",
    "Why is shipping so damn expensive?",
    "Can I get a refund for this shitty shipping service?",
    "My order was marked as delivered, but I never got it!",
    "My package with the eco-friendly products arrived damaged.",
    "Why is the shipping taking so long for the vegan skincare?",
    "I paid for express shipping on the cruelty-free items, why is it late?",
    "The tracking info for my paraben-free order hasn’t updated in days."
]

customer_support_returns_refunds_base = [
    "I want to return a product, can you help?",
    "How do I request a refund for my order?",
    "I would like to cancel my order and receive a refund",
    "The product I received was damaged, how can I return it?",
    "Can you process a return for my recent purchase?",
    "What is your policy on returns and refunds?",
    "What is your return policy?",
    "Can I get a refund for an opened product?",
    "How do I return a product I don't like?",
    "What do I do if I received the wrong item?",
    "How long does it take to process a refund?",
    "How do I go about returning a product that caused an allergic reaction? I have a doctor's note.",
    "Your website isn't letting me process a return for an unwanted product. I haven't even opened it.",
    "It's been over 3 weeks and I still haven't received my refund after returning products. This is unacceptable!",
    "What is the process for returning products that arrived damaged or used? I have images to show.",
    "I want to return a few items for a refund but your policy states products need to be gently used. Define gently used?",
    "How do I go about returning an item that caused an allergic reaction? I have a doctor's note.",
    "Your website isn't allowing me to process a return for an unopened, unwanted product.",
    "It's been over a month and I still haven't received my refund after doing a return!",
    "What's the procedure for returning items that arrived damaged/used? I have pictures.",
    "Your policy says products need to be 'gently used' for returns. Can you define that for me?",
    "How the hell do I return this product?",
    "This product is shit, I want a refund!",
    "Your return process is confusing as fuck.",
    "Can someone help me with a return? This is bullshit.",
    "I need a refund, this product caused an allergic reaction.",
    "Why is your refund process so damn slow?",
    "Can I return this if I've used it once?",
    "What's the fucking policy on refunds?",
    "This product is defective, how do I get my money back?",
    "How do I return this eco-friendly product?",
    "This vegan cream is not working for me, can I get a refund?",
    "Your return process for the plastic-free items is confusing.",
    "Can someone help me with a return on this paraben-free product?"
]

feedback_complaints_base = [
    "I am not happy with the quality of the product.",
    "The packaging was damaged when it arrived.",
    "The product did not meet my expectations.",
    "I am disappointed with the customer service.",
    "The order was incorrect, and I want to complain.",
    "I had an allergic reaction to the micellar water.",
    "Brand_c is no longer as it was!It's cabbage",
    "It has broken my skin",
    "not ok",
    "bad",
    "terrible",
    "cannot be allowed",
    "can't be tolerated",
    "very expensive",
    "not worth it",
    "it's not so good",
    "I'm not happy with the quality of the product.",
    "The packaging was damaged when it arrived.",
    "I had an allergic reaction to the cream.",
    "The product didn't work as advertised.",
    "Customer service was not helpful.",
    "This is pointless",
    "It was all for nothing",
    "Sorry not sorry",
    "It is not done so",
    "not that great",
    "This is not ok",
    "It's not ok",
    "I'm so disappointed with the new foundation I bought from your brand. It oxidizes terribly and makes my skin look orange after a few hours.",
    "Your lip gloss is sticky and gloopy. Why did you change the formula? The old one was so much better.",
    "Your new matte foundation oxidizes and turns orange several shades darker than my skin tone.",
    "The glittery eyeshadow palette you released this season has so much fallout, it's a mess!",
    "Why did you discontinue my holy grail lengthening mascara formula? I'm devastated!",
    "Your liquid eyeliner pens start drying out and getting clumpy within just a couple weeks of use.",
    "The cream blush I bought looks amazing when first applied but doesn't last more than an hour or two.",
    "Your new hydrating primer pills up and goes patchy under foundation.",
    "It's surprising how men have changed today. They have exposed ankles, fitted pants, plucked eyebrows, manicured nails, and skincare routines. They are taking on things traditionally associated with women.",
    "Men seem to have gone wild nowadays. With their bare ankles, tight pants, groomed eyebrows, manicured nails, and dedicated skincare, they're adopting habits typically reserved for women.",
    "Look at how men have transformed today. From showing their ankles and wearing fitted pants to plucking their eyebrows, manicuring their nails, and following skincare routines. They're embracing practices traditionally considered feminine.",
    "It's astonishing how men behave these days. Exposing their ankles, wearing tailored pants, grooming their eyebrows, getting manicures, and following skincare routines. They're taking up practices usually associated with women.",
    "Men have certainly changed today. With their bare ankles, slim-fit pants, groomed eyebrows, polished nails, and skincare habits, they're adopting routines traditionally seen as feminine.",
    "The bronzer in your new face palette is way too orange-toned for my skin.",
    "Why did you discontinue my holy grail brow pomade shade? I'm devastated!",
    "Your cream blush formula looks incredible at first but fades away within an hour or two.",
    "There's an insane amount of fallout every time I use your shimmery eyeshadow palettes.",
    "allergic reaction",
    "You are some tired charlatans !!!",
    "below expectations",
    "It was the only product that managed both dryness and makeup effectively, leaving a light texture on my face. My skin is quite difficult to deal with.",
    "This was the only product that addressed both dryness and makeup seamlessly, providing a light finish on my face. My skin tends to be very challenging.",
    "The product was unique in its ability to handle both dryness and makeup, leaving my face with a light texture. My skin is particularly difficult.",
    "It was the sole product that effectively managed dryness and makeup, leaving a light, pleasant texture on my face. My skin has always been problematic.",
    "This product was the only one that worked for both dryness and makeup, leaving a light feel on my face. I have particularly challenging skin.",
    "This product is absolute shit, I'm never buying it again!",
    "Your customer service is fucking useless!",
    "I'm so pissed off with the quality of this product.",
    "On my dick",
    "Why do you sell such crappy products?",
    "This is the worst experience I've had with any brand, ever.",
    "Who would afford to order?",
    "Stop ripping people off with your shitty products!",
    "Your website is a nightmare to navigate, what the hell?",
    "I'm fed up with your lack of support.",
    "This product broke after one use, what the fuck?",
    "This vegan product did not work for me.",
    "The cruelty-free makeup irritated my skin.",
    "I'm not happy with the quality of this plastic-free item.",
    "This paraben-free cream caused a breakout.",
    "The microplastic-free scrub is too harsh on my skin."
]

feedback_compliments_base = [
    "I love the quality of your products!",
    "The customer service was excellent.",
    "It's my favorite",
    "I just love it! ❤️",
    "I'm using the cream with yellows and I absolutely adore it! ❤️",
    "The cream with yellows is part of my routine, and I just love it! ❤️",
    "I can't get enough of the new set of lipsticks—I absolutely love them! ❤️",
    "I am very satisfied with my purchase.",
    "I admire you for your courage",
    "The packaging was beautiful and intact.",
    "I'm using the night serum and absolutely adore it!",
    "I've been using the serum and I love it!",
    "I use the night serum and I'm a big fan of it!",
    "The vitamin c cream is part of my routine, and I adore it!",
    "I can't get enough of the foaming cleanser—I absolutely love it!",
    "It's gorgeous!",
    "I love your products!",
    "The new serum is amazing!",
    "Great customer service experience!",
    "Your moisturizer is the best I've ever used.",
    "I'm very satisfied with my purchase.",
    "I haven't used Brand_D's revitalizing face serum, ultra-hydrating night cream, gentle foaming cleanser, or refreshing facial mist yet, but reading the ingredients has really piqued my curiosity!",
    "Although I haven't tried them yet, the antioxidant-rich day cream, soothing eye gel, deep-cleansing clay mask, and nourishing lip balm from Brand_D have intrigued me based on their ingredients!",
    "I haven't had the chance to use Brand_D's brightening vitamin C serum, lightweight moisturizer, exfoliating scrub, or calming toner, but the ingredients list has certainly caught my attention!",
    "While I haven't used them so far, the rejuvenating retinol cream, clarifying facial oil, hydrating sheet masks, and gentle makeup remover from Brand_D have aroused my curiosity after reading about their ingredients!",
    "I haven't tried Brand_D's hydrating essence, firming neck cream, balancing facial mist, or protective sunscreen yet, but the ingredients have really sparked my interest!",
    "The product exceeded my expectations.",
    "For me, it works perfectly."
    "It works wonders for me. I've been using it alongside a cleansing gel for several years, and it's greatly reduced my wrinkles."
    "This product has been perfect for me. Paired with a cleansing gel, it's reduced a lot of my wrinkles over the past few years."
    "For me, it has been amazing. I've been using it with a cleansing gel for years, and it has significantly faded my wrinkles. And I'm over 50! Keep experimenting with products until you discover the right one."
    "It's been perfect for me."
    "Just wanted to rave about your new Velvet Blur lippie formula - it's the most comfortable matte I've ever tried!",
    "You guys really hit it out of the park with the shade range for your recent foundation launch. So inclusive!",
    "Your cruelty-free practices and ethically-sourced ingredient philosophy is what keeps me loyal.",
    "The sleek, minimalist aesthetic of your makeup packaging and branding is just chef's kiss.",
    "My favorite products are",
    "perfect!",
    "it is just perfect",
    "the perfect choice",
    "you chose perfect",
    "Your skincare line with probiotics and superfoods is so innovative and effective. Kudos to your brand!",
    "Just wanted to rave about your metallic liquid lipstick formula - it's incredible!",
    "You guys really killed it with the shade diversity in your new concealer range.",
    "Your brand's commitment to sustainable ingredient sourcing is amazing.",
    "The sleek aesthetic and minimal font for your packaging is simply chef's kiss.",
    "Your skincare line for acne-prone skin has been a game changer!",
    "Sounds amazing",
    "Sound divine",
    "ador",
    "bravo",
    "adore",
    "adore it",
    "superb",
    "i waited for this, so excited!",
    "minunat",
    "perfect",
    "is gorgeous",
    "Big up!",
    "wonderfully",
    "This product is fucking amazing, I love it!",
    "It works perfectly for me",
    "Best customer service ever, you guys rock!",
    "I can't believe how well this works, it's fucking awesome!",
    "Your brand never disappoints, always top quality.",
    "Great quality",
    "Super quality",
    "My favorite products from Brand_C are the revitalizing face serum, the ultra-hydrating night cream, the gentle foaming cleanser, and the refreshing facial mist.",
    "From Brand_F, I love the antioxidant-rich day cream, the soothing eye gel, the deep-cleansing clay mask, and the nourishing lip balm.",
    "I can't get enough of Brand_A's brightening vitamin C serum, the lightweight moisturizer, the exfoliating scrub, and the calming toner.",
    "Brand_D's top products for me are the rejuvenating retinol cream, the clarifying facial oil, the hydrating sheet masks, and the gentle makeup remover.",
    "My skincare routine is incomplete without Brand_D's hydrating essence, the firming neck cream, the balancing facial mist, and the protective sunscreen.",
    "no routine without",
    "This is the best thing I've ever bought, hands down.",
    "Thank you for such a fantastic product, I'm a fan for life!",
    "Your products are a game-changer, holy shit!",
    "I’ve never been so happy with a purchase, great job!",
    "Keep up the amazing work, your brand is incredible!",
    "This vegan product is amazing, I love it!",
    "Best cruelty-free makeup I've ever used!",
    "I can't believe how well this plastic-free item works.",
    "This paraben-free moisturizer is fantastic.",
    "The microplastic-free scrub made my skin feel great."
]

feedback_suggestions_base = [
    "I have a suggestion for improving your website.",
    "It would be great if you offered more vegan products.",
    "Can you consider providing samples with orders?",
    "I suggest extending the return policy.",
    "It would be nice to have a loyalty program.",
    "A makeup setting spray would be an awesome new addition to your face product range.",
    "You should consider making your customer loyalty program more rewarding with better perks.",
    "Your fans would love to see you launch more multi-use, versatile cream products that are on-trend.",
    "It's time you extended your brow range with pomades, gels and other tools beyond just pencils.",
    "You need to tap into the huge K-beauty trends like cushion compacts, tone-up creams etc.",
    "A makeup setting spray would be an awesome addition to your existing face line.",
    "You should consider adding more value and perks to your loyalty rewards program.",
    "Launching more multi-tasking hybrid makeup sticks/creams would be so on-trend!",
    "It's time to expand your brow range with pomades, gels and other tools.",
    "You need to tap into the K-beauty cushion compact, tone-up cream trends.",
    "Can you make this product in a larger size? It's too small.",
    "It was good if",
    "It would be great if you offered more fragrance-free options.",
    "Can you add more shades for your foundation?",
    "Consider making a travel-size version of the cleanser.",
    "A larger size of the moisturizer would be appreciated.",
    "Adding a pump to the serum bottle would be convenient.",
    "I’d love to see more vegan options from your brand.",
    "Please consider using eco-friendly packaging.",
    "Can you make a fragrance-free version of this product?",
    "It would be great if you offered sample sizes for new products.",
    "Could you improve the pump on this bottle? It's hard to use.",
    "I'd love to see a more affordable version of this.",
    "Please add more colors to this lipstick range.",
    "Consider adding SPF to your moisturizers.",
    "Can you make this product available in eco-friendly packaging?",
    "I’d love to see more vegan options from your brand.",
    "Please consider using plastic-free packaging.",
    "Can you make a fragrance-free version of this vegan product?",
    "It would be great if you offered more cruelty-free skincare."
]

professional_inquiry_base = [
    "I am interested in a partnership with your brand.",
    "Can I get information on bulk purchasing for my salon?",
    "I want to discuss a business proposal with you.",
    "Is there a professional discount for large orders?",
    "Can we arrange a meeting to discuss a collaboration?",
    "I'm a freelance makeup artist and would love to be considered for opportunities with your brand.",
    "My salon is looking to potentially start carrying your full cosmetics range. Could you provide me info?",
    "I work in beauty media and am interested in getting some products from your upcoming collection for review/coverage purposes.",
    "As a beauty blogger, I'd love the opportunity to collaborate with your brand on tutorials or other content.",
    "I'm a professional MUA and wondered if you offer any pro discounts or loyalty programs I could sign up for?",
    "I'm a freelance makeup artist and would love any opportunities to work with your brand!",
    "My salon is considering carrying your full cosmetics line. Could you provide info?",
    "As a beauty editor, I'd love products from your new collection for editorial coverage.",
    "I'm a beauty blogger interested in potentially collaborating on tutorials/content.",
    "As a pro MUA, I was wondering if you offer any pro discount or loyalty programs?",
    "collaboration with your brand",
    "Can you place me on your PR list?",
    "I am a fashion influencer and i would love to work with yout brand",
    "I'm interested in a wholesale partnership.",
    "Can you provide information on bulk orders?",
    "Do you offer professional discounts?",
    "I'm a beauty blogger interested in collaborating.",
    "Are there any opportunities for product reviewers?",
    "community of active followers",
    "Can i receive a PR box from you?",
    "I am a big fan of your products since they appeared in the country."
    "Would you be interested in a collaboration?",
    "Do you offer any bulk purchase discounts for salons?",
    "I'd like to collaborate with your brand, who should I contact?",
    "Are there any opportunities for brand ambassadors?",
    "I'm interested in becoming a distributor, what's the process?",
    "Can we arrange a meeting to discuss a potential partnership?",
    "Do you offer professional training sessions for using your products?",
    "I'm a beauty blogger interested in reviewing your products.",
    "Is there a media kit available for influencers?",
    "I'm looking to feature your brand in my store, how can we proceed?",
    "Do you offer any bulk purchase discounts for salons that use vegan products?",
    "I'd like to collaborate with your cruelty-free brand, who should I contact?",
    "Are there any opportunities for brand ambassadors focused on sustainable beauty?",
    "I'm interested in becoming a distributor for your plastic-free products, what's the process?",
    "Can we arrange a meeting to discuss a potential partnership on eco-friendly items?"
]

others_base = [
    "The weather is nice today.",
    "I am going for a walk in the park.",
    "What are your plans for the weekend?",
    "I enjoy cooking in my free time.",
    "The movie I watched last night was very entertaining.",
    "How do you spend your holidays?",
    "I love traveling to new places around the world.",
    "My favorite sport is basketball.",
    "Do you like listening to music while working?",
    "When is your big annual sale happening this year? I need to start budgeting for it!",
    "Do you happen to know if the brand is cruelty-free and not sold in any markets that require animal testing?",
    "As a woman of color, I'd love to see your brand showcase more diversity in your campaigns and advertising.",
    "Where are your products manufactured? I'm trying to only support brands with ethical supply chains.",
    "I saw your new brand ambassadors and am so excited for the future of the company!",
    "When does your big annual sale event happen this year? I need to start budgeting!",
    "Is your brand cruelty-free and not sold where animal testing is required by law?",
    "As a WOC, I'd love to see your campaigns showcase more racial diversity.",
    "Where are your products manufactured? Looking to support ethical supply chains.",
    "I'm so excited about your brand's new celebrity ambassadors!",
    "blowjob",
    "Can I use this product if I'm pregnant?",
    "Do you offer samples?",
    "What are your business hours?",
    "Can I change my account details?",
    "Do you have a loyalty program?",
    "stupid",
    "WIN a year’s supply of our premium beauty products! Like this post, tag 3 friends, and share to enter! #Giveaway #BeautyWin #Freebies",
    "Transform your skin with our magical elixir! Order now and get 50% off your first purchase! Use code: MAGIC50 at checkout. Limited time offer! #Skincare #BeautyDeals",
    "Unleash the secret to flawless skin! Click the link in our bio to discover our top-rated beauty products and enjoy a 30% discount! #SkincareRoutine #Discounts",
    "Say goodbye to wrinkles and hello to youthful skin! Our revolutionary anti-aging serum is now available. Shop now and get a free sample with every order! #AntiAging #BeautyTips",
    "Flash Sale Alert! Get your favorite beauty products at up to 70% off. Hurry, while stocks last! #FlashSale #BeautyBargains",
    "Exclusive offer for our followers! Buy one, get one free on selected items. Shop now and save! #BOGO #CosmeticsDeals",
    "Discover the ultimate skincare routine with our new collection. Follow the link and get 20% off your first order. #Skincare #BeautySavings",
    "Get a flawless complexion with our best-selling foundation. Limited time only, buy now and get a free brush! #MakeupDeals #BeautyEssentials",
    "Join our loyalty program and earn points with every purchase. Redeem points for exclusive discounts and free products! #LoyaltyRewards #BeautyProgram",
    "New product launch! Check out our latest range of organic skincare products. Order today and get free shipping on all orders. #NewArrivals #OrganicBeauty",
    "WIN a year’s supply of our premium beauty products! Like this post, tag 3 friends, and share to enter! #Giveaway #BeautyWin #Freebies",
    "Transform your skin with our magical elixir! Order now and get 50% off your first purchase! Use code: MAGIC50 at checkout. Limited time offer! #Skincare #BeautyDeals",
    "Unleash the secret to flawless skin! Click the link in our bio to discover our top-rated beauty products and enjoy a 30% discount! #SkincareRoutine #Discounts",
    "Say goodbye to wrinkles and hello to youthful skin! Our revolutionary anti-aging serum is now available. Shop now and get a free sample with every order! #AntiAging #BeautyTips",
    "Flash Sale Alert! Get your favorite beauty products at up to 70% off. Hurry, while stocks last! #FlashSale #BeautyBargains",
    "Exclusive offer for our followers! Buy one, get one free on selected items. Shop now and save! #BOGO #CosmeticsDeals",
    "Discover the ultimate skincare routine with our new collection. Follow the link and get 20% off your first order. #Skincare #BeautySavings",
    "Get a flawless complexion with our best-selling foundation. Limited time only, buy now and get a free brush! #MakeupDeals #BeautyEssentials",
    "Join our loyalty program and earn points with every purchase. Redeem points for exclusive discounts and free products! #LoyaltyRewards #BeautyProgram",
    "New product launch! Check out our latest range of organic skincare products. Order today and get free shipping on all orders. #NewArrivals #OrganicBeauty",
    "Special offer: Get glowing skin in just 7 days with our Vitamin C serum. Buy now and receive a 15% discount. Use code GLOW15 at checkout. #Skincare #BeautyOffer",
    "Don't miss out on our biggest sale of the year! All beauty products up to 60% off. Shop now and save big. #BeautySale #CosmeticsDeals",
    "Experience the magic of our new hydrating mask. Order now and get a free travel-size cleanser with your purchase. #SkincareMagic #FreeGift",
    "Revitalize your skin with our collagen-boosting cream. Shop today and enjoy a complimentary beauty consultation. #AntiAging #FreeConsultation",
    "Limited time only: Get our entire lip care collection for just $29.99. Click the link to shop now. #LipCare #BeautyBundle",
    "Discover the secret to perfect brows with our new eyebrow kit. Buy now and get a 20% discount. #BeautySecret #BrowsOnFleek",
    "Treat yourself to luxury with our exclusive beauty box subscription. Subscribe today and get your first box free. #BeautyBox #SubscriptionOffer",
    "Unlock the power of nature with our organic skincare range. Order now and receive a free eco-friendly tote bag. #OrganicBeauty #EcoFriendly",
    "Upgrade your beauty routine with our new line of cruelty-free cosmetics. Shop now and take 10% off your first order. #CrueltyFree #BeautyRoutine",
    "Back in stock: Our fan-favorite moisturizer. Hurry, quantities are limited. #BackInStock #SkincareEssentials",
    "Looking for the perfect gift? Check out our beauty gift sets. Buy one, get one 50% off. #GiftSets #BeautyGifts",
    "Say hello to clear skin with our acne-fighting products. Order today and get a free consultation with our skincare expert. #ClearSkin #FreeConsultation",
    "Exclusive online offer: Get a free lip balm with any purchase over $50. Shop now and pamper your lips. #FreeGift #LipCare",
    "Achieve a flawless finish with our new foundation range. Buy one, get one free on all shades. #Foundation #BOGO",
    "Pamper yourself with our luxurious spa collection. Get 25% off when you buy the complete set. #SpaCollection #BeautySavings",
    "New customer special: Enjoy 20% off your first order when you sign up for our newsletter. #NewCustomer #DiscountOffer",
    "Get salon-quality hair at home with our new haircare line. Order now and receive a free hairbrush. #Haircare #FreeGift",
    "Join our VIP club and get exclusive access to new products, special discounts, and more. Sign up today! #VIPClub #ExclusiveAccess",
    "Free shipping on all orders over $75. Shop now and save on your favorite beauty products. #FreeShipping #BeautySavings",
    "Limited edition alert: Our new eyeshadow palette is here. Shop now before it's gone. #LimitedEdition #EyeshadowPalette",
     "https://",
    "Can you explain why this product is better than the competitors?",
    "Why did you discontinue my favorite product? This sucks!",
    "Do you have a store locator on your website?",
    "What’s the difference between these two products?",
    "Can you recommend a product for my specific skin type?",
    "I need advice on a skincare routine, can you help?",
    "Why are your products so highly rated? What's the secret?",
    "Can someone help me choose the right shade for my skin?",
    "What do your customers say about this product?",
    "Fuck this, I'm done!",
    "This shit is unbelievable.",
    "Damn, that was close!",
    "What the hell is going on?",
    "He's such a bastard.",
    "She's acting like a bitch.",
    "This is a load of crap.",
    "Stop being such a dick.",
    "Don't be an asshole.",
    "I need to take a piss.",
    "He's a total prick.",
    "Don't be a douchebag.",
    "Quit acting like a jackass.",
    "This is complete bullshit.",
    "He's got a huge cock.",
    "That motherfucker cut me off in traffic.",
    "She called him a cunt.",
    "Screw you and your ideas.",
    "He's such a twat.",
    "That's bloody fantastic!",
    "Can you explain why your products are better for the environment?",
    "Why did you discontinue my favorite cruelty-free product?",
    "Do you have a store locator on your website for eco-friendly products?",
    "What’s the difference between your vegan and regular product lines?",
    "Can someone help me choose the right shade for my skin in your cruelty-free range?"
]

# Number of unique samples per category
num_unique_samples_per_category = 500

# Generate synthetic data
product_inquiry_availability_data = generate_unique_synthetic_data(product_inquiry_availability_base, "Product Inquiry-Availability", num_unique_samples_per_category)
product_inquiry_ingredients_data = generate_unique_synthetic_data(product_inquiry_ingredients_base, "Product Inquiry-Ingredients", num_unique_samples_per_category)
product_inquiry_usage_instructions_data = generate_unique_synthetic_data(product_inquiry_usage_instructions_base, "Product Inquiry-Usage Instructions", num_unique_samples_per_category)
product_inquiry_price_data = generate_unique_synthetic_data(product_inquiry_price_base, "Product Inquiry-Price", num_unique_samples_per_category)
product_inquiry_recommendations_data = generate_unique_synthetic_data(product_inquiry_recommendations_base, "Product Inquiry-Recommendations", num_unique_samples_per_category)
customer_support_order_status_data = generate_unique_synthetic_data(customer_support_order_status_base, "Customer Support-Order Status", num_unique_samples_per_category)
customer_support_shipping_issues_data = generate_unique_synthetic_data(customer_support_shipping_issues_base, "Customer Support-Shipping Issues", num_unique_samples_per_category)
customer_support_returns_refunds_data = generate_unique_synthetic_data(customer_support_returns_refunds_base, "Customer Support-Returns and Refunds", num_unique_samples_per_category)
feedback_complaints_data = generate_unique_synthetic_data(feedback_complaints_base, "Feedback-Complaints", num_unique_samples_per_category)
feedback_compliments_data = generate_unique_synthetic_data(feedback_compliments_base, "Feedback-Compliments", num_unique_samples_per_category)
feedback_suggestions_data = generate_unique_synthetic_data(feedback_suggestions_base, "Feedback-Suggestions", num_unique_samples_per_category)
professional_inquiry_data = generate_unique_synthetic_data(professional_inquiry_base, "Professional Inquiry", num_unique_samples_per_category)
others_data = generate_unique_synthetic_data(others_base, "Others", num_unique_samples_per_category)

# Combine all data
all_data = (product_inquiry_availability_data + product_inquiry_ingredients_data + product_inquiry_usage_instructions_data +
            product_inquiry_price_data + product_inquiry_recommendations_data + customer_support_order_status_data + customer_support_shipping_issues_data +
            customer_support_returns_refunds_data + feedback_complaints_data + feedback_compliments_data +
            feedback_suggestions_data + professional_inquiry_data + others_data)

random.shuffle(all_data)

# Convert to DataFrame
df = pd.DataFrame(all_data)

# Save to CSV
df.to_csv('intent-data.csv', index=False)

print("saved")
# Out:
# saved

# %%
import pandas as pd
import random
import itertools
import nlpaug.augmenter.word as naw

# Function to create unique synthetic data
def generate_unique_synthetic_data(base_texts, intent, num_samples):
    unique_data = list(itertools.islice(itertools.cycle(base_texts), num_samples))
    return [{"text": text, "intent": intent} for text in unique_data]

# Function to augment text data
def augment_text(text, num_aug=5):
    aug = naw.SynonymAug(aug_src='wordnet')
    augmented_texts = [aug.augment(text) for _ in range(num_aug)]
    return augmented_texts

# Number of unique samples per category
num_unique_samples_per_category = 500

# Define base texts for each category (Skipped here for brevity)
categories = {
    "Product Inquiry-Availability" : [
    "Is the new lipstick collection available?",
    "Is the hydrating serum still in stock?",
    "Do you have the anti-aging cream available?",
    "Can I purchase the new matte foundation online?",
    "Is the brightening mask available at your stores?",
    "When will the charcoal face wash be back in stock?",
    "When will the latest foundation be back in stock?",
    "Are the skincare products available for bulk purchases?",
    "Do you have the hair straighteners in stock?",
    "Can I pre-order the new moisturizer?",
    "Is the new matte lipstick shade 'Velvet Rouge' still available? It's sold out online.",
    "When will you be restocking the Radiant Glow highlighter palette? I need to get my hands on it!",
    "Are the limited edition holiday brush sets still in stores or were they an online exclusive?",
    "Do you know if the Porcelain shade of your foundation stick is being discontinued? I can't find it anymore.",
    "I'm looking for a specific shimmery eyeshadow single called 'Gilded' but can't locate it on your website.",
    "I've searched this everywhere and I couldn't find it. Is it still available in Romania?",
    "Can you help me find this cream? Thanks!",
    "no longer in stock",
    "I'd like to ask if the cream for normal and dry skin is becoming more expensive. I bought it from a site, and the tube is larger but at the same price. I'm worried it might not be original.",
    "I'm curious if the cream for normal and dry skin is increasingly costly. I got it from a website, and although the tube is bigger, the price remains the same. Could it be that it's not genuine?",
    "I wanted to ask if the price of the cream for normal and dry skin is rising. I purchased it from an online store, and the tube seems taller for the same price. I suspect it might not be authentic.",
    "Can you tell me if the cream for normal and dry skin is getting pricier? I ordered it from a site, and while the tube is larger, the price hasn't changed. I'm concerned it might be a counterfeit.",
    "I'm wondering if the cream for normal and dry skin is more expensive now. I bought it online, and the tube is higher but still at the same price. I'm worried it might not be the original product.",
    "Why don't you bring the Red shampoo in country? You only sell it abroad",
    "Is the Velvet Matte Liquid Lipstick in the shade Turkish Rose still being produced?",
    "Your website says the Pro Contour Palette is out of stock. When can I expect a restock?",
    "I can't seem to find the Featherlight Skin Tint anywhere! Has it been discontinued?",
    "Do you know if the holiday Glam Goddess Brush Set will be released again this year?",
    "Hi! Is this product still available?",
    "I looked everywhere for a moisturizer with a gel texture, but it was only available on two websites, both charging double the price.",
    "I searched extensively for a shampoo with a honey formula, yet I could only find it on two sites, and both had it priced at twice the usual rate.",
    "I tried to find a serum with a velvet finish all over the internet, but I only located it on two platforms, where it was listed at double the cost.",
    "I scoured the web for a cleanser with a mousse consistency, but it was only present on two websites, both offering it at double the normal price.",
    "I hunted for a foundation with a cream-to-powder formula everywhere online, and it was only available on two sites, each pricing it at double the standard amount.",
    "I looked everywhere for this product and I couldn’t find it! Can you tell me it’s still produced?",
    "I bought this product one year ago from France and I was really pleased with it. Now I’m living in Romania and I can’t find it anywhere. Can you please help me?",
    "Is it in MegaImage?",
    "Can I find it in Romania?",
    "Do you still produce the shade number 24?",
    "Can I still find the old version of this product?",
    "I want to know if this product will ever be available again.",
    "I couldn't find it in supermarkets.",
    "When will we be able to purchase it in Romania?",
    "When is it coming in Romania?",
    "I couldn't find it in Carrefour, I'm gonna look for it in other stores.",
    "Can it only be purchased online?",
    "In which stores can I find it?",
    "Which are the stores where I can't find the product?",
    "Do you sell it in pharmacies too?",
    "Can I find it in any pharmacy?",
    "Is it available in stores and in pharmacies too?",
    "When is the release date?",
    "Is it gonna be available in dm?",
    "Is it sold out?",
    "I searched the micellar water with milk texture.Why didn't there anywhere?I searched everywhere!",
    "When it's going to be back on stock?",
    "How can I be notified if it's back on stock?",
    "why don't you bring to the Romanian markets and oily hair shampoo?",
    "The best products you have are not marketed at all in the country.",
    "Are these the last products?",
    "Is this foundation still fucking available?",
    "Do you have this lipstick in stock, or is it out of stock again?",
    "I can't find this product on your site, is it available or not?",
    "Is the moisturizer back in stock yet? I'm tired of waiting.",
    "Are you ever going to restock this damn eyeshadow?",
    "When will you have more of this fucking product?",
    "Why is this always out of stock? Do you even restock?",
    "Is there any chance you'll get more of this soon? It's fucking annoying!",
    "Is this cruelty-free product available?",
    "When will you restock the vegan lipstick?",
    "Why is the eco-friendly packaging always out of stock?",
    "When can I buy the plastic-free skincare set again?",
    "Is the paraben-free moisturizer available or not?"
],

    "Product Inquiry-Ingredients": [
    "What are the ingredients of the new lipstick?",
    "What are the main ingredients in the revitalizing night cream?",
    "Does the hydrating serum contain hyaluronic acid?",
    "Are there any parabens in the anti-aging lotion?",
    "Can you provide the full ingredient list for the brightening mask?",
    "Is the face wash free from sulfates?",
    "Does the foundation contain any parabens?",
    "Are the skincare products vegan?",
    "Is the hair serum free from sulfates?",
    "Can you provide the ingredient list for the new moisturizer?"
    "What are the main ingredients in your Vitamin C serum? I'm trying to avoid specific chemicals.",
    "I have an almond allergy - do any of your products contain nut oils or derivatives?",
    "Are the mineral sunscreens you use nano or non-nano particles? I prefer non-nano for safety.",
    "Your Detox clay mask contains charcoal, right? Just want to double check before purchasing.",
    "I noticed your concealer has dimethicone listed - is this a new formulation change?",
    "Does is contain niacinamides?",
    "bakuchiol",
    "cerammide",
    "collagen",
    "glycerin",
    "glycolic acid",
    "hyaluronic acid",
    "keratin",
    "lactic acid",
    "retinol",
    "salicylic acid",
    "silicon",
    "squalane",
    "squalene",
    "algae",
    "aloe vera",
    "apricot",
    "argan oil",
    "blue tansy",
    "caffein",
    "calendula",
    "CBD",
    "charcoal",
    "cinnamon",
    "coconut",
    "manuka honey",
    "hibiscus",
    "essential oil",
    "ginseng",
    "honey",
    "jojoba",
    "lavender",
    "mushrooms",
    "olive oil",
    "peptides",
    "probiotics",
    "shea butter",
    "vitamin a",
    "vitamin c",
    "vitamin e",
    "does vitamin c increase skin glow?"
    "what does vitamin c do to your face",
    "vitamin c bightens face",
    "is 50 too late to start retinol?"
    "can i put retinol under my eyes?",
    "does hyaluronic acid raise blood pressure?"
    "what's better retinol or hyaluronic acid",
    "I have a nut allergy. Do any of your eyeshadow palettes contain nut-derived ingredients?",
    "If it has an alcohol distorted and perfume I will not buy",
    "What percentage of your skincare line is vegan and free of animal by-products?",
    "Your Detoxifying Clay Mask contains bentonite clay, right? Just want to confirm before purchasing.",
    "I'm trying to avoid alcohols in my skincare. Are any of your toners or mists alcohol-free?",
    "Does it contain perfume?",
    "Does it contain alcohol?",
    "Does it contain niacinamide?",
    "Does it contain AHA BHA?",
    "Does it contain ceramide?",
    "Does it contain peptides?",
    "Does it contain salicylic acid?",
    "Does it contain parabens?",
    "Will the perfume irritate my sensitive skin?",
    "Can I use it if I'm allergic to hyaluronic acid?",
    "Can I use it if I'm taking Roaccutane? Are the ingredients compatible with this treatment?",
    "Is it perfume free?",
    "Is it alcohol free?",
    "Vitamin C increase the sunscreens effects?",
    "Due to the presence of retinol, if I'm using it in the night, do I need to apply SPF in the morning?",
    "Do the ingredients irritate the skin?",
    "Is this product suitable for sensitive skin also?",
    "Is this product suitable for acne skin?",
    "Is it vegan?",
    "All the ingredients are vegan?",
    "So due to the ingredients it's supposed to be as good for the dried skin as it is for the normal skin. Right?",
    "Does it contain allergens?",
    "What the hell is in your new serum?",
    "Does this product contain any parabens?",
    "Is this shampoo sulfate-free or what?",
    "Can you provide a full ingredient list for this lotion?",
    "Are there any animal-derived ingredients in this product?",
    "Are these ingredients safe for sensitive skin, or is it all bullshit?",
    "Are any of these ingredients known to cause cancer?",
    "Does this product have any allergens? I can't risk it.",
    "What the fuck are the active ingredients in this?",
    "Is this cruelty-free product available?",
    "When will you restock the vegan lipstick?",
    "Why is the eco-friendly packaging always out of stock?",
    "When can I buy the plastic-free skincare set again?",
    "Is the paraben-free moisturizer available or not?"
],

    "Product Inquiry-Usage Instructions": [
    "How do I apply the new foundation?",
    "Can you provide usage instructions for the hair straighteners?",
    "How often should I use the face mask?",
    "Can the serum be used daily?",
    "How do I use the vitamin C serum?",
    "What's the best way to apply the night cream?",
    "Can I use this mask more than once a week?",
    "Should I apply the toner before or after moisturizing?",
    "Is this product suitable for daily use?",
    "What are the directions for using the new sunscreen?",
    "How should I apply and blend your cream contour palette? Looking for technique tips.",
    "What's the best way to remove your long-wear liquid lipsticks without drying out my lips?",
    "Should I use the illuminating primer before or after my makeup? Does it go under foundation?",
    "How many pumps of the Vitamin C serum do you recommend using for the full face?",
    "Do you have any tutorials on achieving the perfect cat-eye liner look with your gel pencil?",
    "What's the best way to apply your Radiant Glow Body Shimmer?♀️",
    "Should I use the Mattifying Face Primer before or after my foundation?",
    "Any tips for blending out the cream contour shades from your Pro Palette?",
    "Around how many pumps of serum would you recommend for the full face and neck?",
    "Can it be used in combination with vitamin C?",
    "Can it be used in combination with retinol?",
    "Is it a night routine product or a day one?",
    "Do I need to apply SPF in the morning if I'm putting this face cream on before I sleep?",
    "Can I introduce it in my everyday routine?",
    "Does is work as a second step in a double cleansing?",
    "Does it remove makeup too?",
    "Can I use it on the eye area too?",
    "Are you sure that it's suitable for the body and the face too? Isn't it going to be too harsh for the skin?",
    "Should I use a",
    "Should I use it if I'm going to do a chemical peeling the next day?",
    "Is it ok to use on an irritate skin (after a cosmetic treatment)?",
    "How should I introduce this product in my routine if I'm using retinol?",
    "Is it compatible with a niacinamide serum?",
    "Can I apply this aloe gel after I had a mechanical peeling?",
    "Do I need to wash the hair once or twice?",
    "How much time should I leave it to act on the skin?",
    "How much should I leave it on the hair?",
    "3 minutes is enough for it to action?",
    "Do I need to rinse with water after use?",
    "If I'm leave it longer on my hair, the color it's gonna be stronger?",
    "Can I apply the conditioner and the mask too?",
    "First I apply the serum then the cream?",
    "Mist after or before the cream?",
    "Can I use the mist on top of the makeup?",
    "Is this face cream friendly with makeup? Can I use it as a primer? I saw that it contains panthenol so it's supposed to hydrate the skin.",
    "How many times per week is it indicate to use?",
    "How the hell do I use this product?",
    "Can someone tell me how to apply this properly?",
    "Do I need to use this on dry or damp skin?",
    "Are there any specific steps to follow when using this mask?",
    "Can I use this daily, or will it screw up my skin?",
    "Is there a tutorial on how to use this properly?",
    "Should I apply this before or after my moisturizer?",
    "What’s the best way to use this, without fucking it up?",
    "How do I use this eco-friendly product?",
    "Can someone explain how to apply this vegan cream?",
    "Is this safe for daily use on sensitive skin?",
    "What are the instructions for using this cruelty-free serum?",
    "How should I apply this pollution-fighting face mask?"
],

    "Product Inquiry-Price": [
    "What is the price of the new lipstick?",
    "How much does the latest foundation cost?",
    "How much does the anti-aging serum cost?",
    "What's the price of the new moisturizer?",
    "Is there a discount on the face scrub?",
    "Can you tell me the price of the entire skincare set?",
    "How much is the shipping cost for this product?",
    "Are there any discounts available for the skincare products?",
    "What is the price range for the hair care products?",
    "Can you provide the price details for the new moisturizer?",
    "Hi, how much does the limited edition Smokey Eye palette retail for before taxes?",
    "What are the prices for the travel size versions of your best-selling mascaras?",
    "I'm looking at the Radiant Finishing powder online but the price seems high - is it sold individually or as a duo/set?",
    "Could you let me know the cost of your Charcoal Detox face mask? Not seeing it listed anywhere.",
    "Are the prix fixe brush sets discounted from the individual brush prices if purchased separately?",
    "What's the price point for your new High-Def Liquid Highlight? Couldn't find it listed."
    "Do you happen to know the cost of your top-selling mascara in the travel/mini size?"
    "The Body Butter seems expensive - is it sold individually or as part of a set?"
    "Could you let me know how much your cult-favorite Radiance Primer retails for?",
    "Price",
    "Price?",
    "Price?",
    "How much?",
    "How much does it cost?",
    "What's the cost of this product?",
    "When are the sales coming?",
    "Will it be reduced on Black Friday?",
    "Will it be reduced at the end of the month?",
    "How much is it going to be after the discount?",
    "Any discount?",
    "How can I receive a discount?",
    "How much does this product cost, for fuck's sake?",
    "Is this really worth $50? Seems like a rip-off.",
    "Why is this so damn expensive?",
    "Do you have any discounts for this item?",
    "Can you justify the price of this shit?",
    "What's the price on this? Can't find it anywhere!",
    "Are there any hidden costs with this?",
    "How the hell is this so pricey?",
    "Do you offer price matching for this product?",
    "How much does this vegan product cost?",
    "Why is this cruelty-free makeup so expensive?",
    "Is this plastic-free packaging worth the price?",
    "Do you offer any discounts on eco-friendly products?",
    "What is the price of this microplastic-free scrub?"
],

    "Product Inquiry-Recommendations": [
    "I'm looking for a long-wearing foundation for combination skin. What would you recommend?",
    "Can you suggest a good hydrating serum to use under makeup? My skin has been so dry lately.",
    "I need a volumizing mascara that doesn't clump or flake. Any recommendations from your line? ",
    "What do you recommend for dry skin?",
    "Can you suggest a good moisturizer for oily skin?",
    "What's the best product for reducing wrinkles?",
    "Do you have any recommendations for a daily sunscreen?",
    "Which cleanser would you suggest for sensitive skin?",
    "What's your best highlighter for a blinding glow? I have medium/tan skin.",
    "I recommend that you encapsulate the serum with pure vitamin C as it oxidizes very quickly.",
    "I'm interested in trying your brand's brow products. Which one would you suggest for full, feathered brows? ",
    "Do you have any color correcting products you'd recommend for my dark circles and redness? ",
    "I'm looking to try a lightweight tinted moisturizer instead of foundation. What's a good one for light coverage?",
    "What lip product would you suggest for a long-lasting, comfortable matte lip color? ",
    "Could you recommend a good face sunscreen that wears well under makeup? I need SPF 30+. ",
    "I have acne-prone skin and am interested in your skincare line. Where should I start? What products do you suggest?",
    "I'm in the market for a new eyeshadow palette. Which one from your line would you recommend for neutral, everyday looks?",
    "Can you suggest a good blush formula that doesn't accentuate texture or look cakey? I have dry, mature skin.",
    "I need a setting powder that doesn't look dry or cakey under my eyes. What would you recommend for brightening too?",
    "What is your best liquid eyeliner pen for a precise winged liner look? I need something super black and smudge-proof.",
    "I'm hoping to find a good primer that smooths out pores and texture. Any recommendations for your gripping or filling primers?",
    "Do you have any cream or liquid bronzer/contour products you'd recommend for achieving a natural, subtle contour?",
    "I'm looking to try one of your glow/radiance boosting primers or setting sprays. Which one would you suggest?",
    "What would be your recommended skincare routine for someone with combination, acne-prone skin in their 30s?",
    "I want to try one of your dewy, natural finish foundations. Which one has good coverage but still looks like skin?",
    "Can you recommend a good matte bronzer shade for light-medium warm olive skin tones from your line?",
    "What lip liner would you suggest for preventing feathering and making lipstick last longer?",
    "I'm searching for an under-eye corrector to brighten and color correct dark circles. Any recommendations?",
    "Your brow products look amazing! Which one would you suggest for someone wanting feathery, laminated brows?",
    "I need a good oil-control product to mattify throughout the day. Do you have any mattifying sprays or blotting products?",
    "What lipstick formula would you recommend for a comfortable, long wearing red shade?",
    "I want you to recommmend a day and night cream for +50,thank you!",
    "Can you recommend a fucking good moisturizer for dry skin?",
    "I need a serum that actually works, any suggestions?",
    "What's the best product you have for acne?",
    "Can you suggest something for sensitive skin that won’t cause breakouts?",
    "Are there any products that help with dark spots?",
    "I need a recommendation for an anti-aging cream that’s worth the damn money.",
    "What’s the best product for reducing wrinkles?",
    "Do you have a good recommendation for a vegan foundation?",
    "What should I use for extremely dry, flaky skin?",
    "Can you recommend a good vegan moisturizer?",
    "I need a cruelty-free serum that works, any suggestions?",
    "What eco-friendly product do you recommend for oily skin?",
    "What's the best product for acne that doesn't contain microplastics?",
    "Can you suggest a plastic-free option for sensitive skin?"
],

    "Customer Support-Order Status": [
    "Can you provide an update on my order status?",
    "My order hasn't arrived yet, can you check?",
    "When will my order be delivered?",
    "How do I track my order status?",
    "Is my order still on its way?",
    "I want to buy this",
    "Can you update me on my order status?",
    "Has my order shipped yet?",
    "When will my order be delivered?",
    "Is there a way to track my order?",
    "Why is my order taking so long?",
    "i want a shampoo and a mask",
    "i will buy the serum",
    "I placed an order a week ago but haven't received any shipping notification yet. Can you check the status?",
    "My order confirmation shows delivered but I haven't received my package yet. What do I do?",
    "It's been 10 days and my order still shows processing with no movement. When will it ship out?",
    "I got an order delivery exception notification but no other details. Is my order lost or delayed?",
    "I received someone else's order by mistake instead of my own. This needs to be resolved urgently!",
    "Hi, I placed an order last week but haven't received any shipping updates yet. Can you check?",
    "My order status shows delivered but I haven't actually received my package. What gives?",
    "It's been 10 days and my order is still processing with no movement. When will it ship?",
    "I got a delivery exception notice for my order but no other details. Is it lost or delayed?",
    "How can I verify my order status?",
    "Where I can see the status of my order?",
    "I ordered it yesterday. Will it arrive on Monday?",
    "How many business days does it take for the package to arrive?",
    "Where can I see if my package pass the customs?",
    "Where the fuck is my order?",
    "My order is delayed, what the hell is going on?",
    "Unde dracu este comanda mea?",
    "I haven’t received any updates on my order, this is bullshit.",
    "Can you check the status of my order? It's been weeks!",
    "Why the fuck hasn’t my order shipped yet?",
    "Can someone tell me if my order is coming or not?",
    "This delay is unacceptable, what the hell?",
    "I need an update on my order status immediately!",
    "Why is my order still processing? This is ridiculous!",
    "Where is my order for the cruelty-free products?",
    "My order for the vegan makeup is delayed, what's going on?",
    "I haven’t received any updates on my order for the plastic-free set.",
    "Why hasn’t my order for the paraben-free items shipped yet?"
],

    "Customer Support-Shipping Issues": [
    "There was an issue with the shipping address, can you help?",
    "My order was shipped to the wrong address, what should I do?",
    "Can you assist with the shipping delay?",
    "The tracking information for my order is incorrect.",
    "I need to change the shipping address for my order.",
    "My order shipment arrived damaged with products spilling out of the boxes. Who do I contact?",
    "I received the wrong item than what I had ordered. The product was also used! I need a refund.",
    "My order was shipped to the wrong address although I had entered the right one. How to re-route it?",
    "The shipping carrier has had my package for 2 weeks without any update. What is going on here?",
    "I paid extra for express shipping but my order took just as long as regular ground shipping!",
    "My shipment arrived with products leaking out of the damaged boxes. Who do I contact?",
    "I received someone else's order instead of my own items! This needs to be resolved.",
    "My order was shipped to the incorrect address even though I double checked it. Can it be rerouted?",
    "The shipping carrier has had my package for over 2 weeks now with zero updates!",
    "waiting for my order",
    "waiting to receive my order",
    "waiting to get my order",
    "My package hasn't arrived yet.",
    "The delivery address is incorrect.",
    "I received a damaged product.",
    "My order was shipped to the wrong address.",
    "How can I change my shipping details?",
    "My package arrived damaged, what the hell?",
    "Why is the shipping taking so fucking long?",
    "I paid for express shipping, why is it late?",
    "The tracking info hasn’t updated in days, what the fuck?",
    "Can you resend my order? It never arrived!",
    "This is the second time my package has been lost, what the hell?",
    "Why is shipping so damn expensive?",
    "Can I get a refund for this shitty shipping service?",
    "My order was marked as delivered, but I never got it!",
    "My package with the eco-friendly products arrived damaged.",
    "Why is the shipping taking so long for the vegan skincare?",
    "I paid for express shipping on the cruelty-free items, why is it late?",
    "The tracking info for my paraben-free order hasn’t updated in days."
],

    "Customer Support-Returns and Refunds": [
    "I want to return a product, can you help?",
    "How do I request a refund for my order?",
    "I would like to cancel my order and receive a refund",
    "The product I received was damaged, how can I return it?",
    "Can you process a return for my recent purchase?",
    "What is your policy on returns and refunds?",
    "What is your return policy?",
    "Can I get a refund for an opened product?",
    "How do I return a product I don't like?",
    "What do I do if I received the wrong item?",
    "How long does it take to process a refund?",
    "How do I go about returning a product that caused an allergic reaction? I have a doctor's note.",
    "Your website isn't letting me process a return for an unwanted product. I haven't even opened it.",
    "It's been over 3 weeks and I still haven't received my refund after returning products. This is unacceptable!",
    "What is the process for returning products that arrived damaged or used? I have images to show.",
    "I want to return a few items for a refund but your policy states products need to be gently used. Define gently used?",
    "How do I go about returning an item that caused an allergic reaction? I have a doctor's note.",
    "Your website isn't allowing me to process a return for an unopened, unwanted product.",
    "It's been over a month and I still haven't received my refund after doing a return!",
    "What's the procedure for returning items that arrived damaged/used? I have pictures.",
    "Your policy says products need to be 'gently used' for returns. Can you define that for me?",
    "How the hell do I return this product?",
    "This product is shit, I want a refund!",
    "Your return process is confusing as fuck.",
    "Can someone help me with a return? This is bullshit.",
    "I need a refund, this product caused an allergic reaction.",
    "Why is your refund process so damn slow?",
    "Can I return this if I've used it once?",
    "What's the fucking policy on refunds?",
    "This product is defective, how do I get my money back?",
    "How do I return this eco-friendly product?",
    "This vegan cream is not working for me, can I get a refund?",
    "Your return process for the plastic-free items is confusing.",
    "Can someone help me with a return on this paraben-free product?"
],

    "Feedback-Complaints": [
    "I am not happy with the quality of the product.",
    "The packaging was damaged when it arrived.",
    "The product did not meet my expectations.",
    "I am disappointed with the customer service.",
    "The order was incorrect, and I want to complain.",
    "I had an allergic reaction to the micellar water.",
    "Brand_c is no longer as it was!It's cabbage",
    "It has broken my skin",
    "not ok",
    "bad",
    "terrible",
    "cannot be allowed",
    "can't be tolerated",
    "very expensive",
    "not worth it",
    "it's not so good",
    "I'm not happy with the quality of the product.",
    "The packaging was damaged when it arrived.",
    "I had an allergic reaction to the cream.",
    "The product didn't work as advertised.",
    "Customer service was not helpful.",
    "This is pointless",
    "It was all for nothing",
    "Sorry not sorry",
    "It is not done so",
    "not that great",
    "This is not ok",
    "It's not ok",
    "I'm so disappointed with the new foundation I bought from your brand. It oxidizes terribly and makes my skin look orange after a few hours.",
    "Your lip gloss is sticky and gloopy. Why did you change the formula? The old one was so much better.",
    "Your new matte foundation oxidizes and turns orange several shades darker than my skin tone.",
    "The glittery eyeshadow palette you released this season has so much fallout, it's a mess!",
    "Why did you discontinue my holy grail lengthening mascara formula? I'm devastated!",
    "Your liquid eyeliner pens start drying out and getting clumpy within just a couple weeks of use.",
    "The cream blush I bought looks amazing when first applied but doesn't last more than an hour or two.",
    "Your new hydrating primer pills up and goes patchy under foundation.",
    "It's surprising how men have changed today. They have exposed ankles, fitted pants, plucked eyebrows, manicured nails, and skincare routines. They are taking on things traditionally associated with women.",
    "Men seem to have gone wild nowadays. With their bare ankles, tight pants, groomed eyebrows, manicured nails, and dedicated skincare, they're adopting habits typically reserved for women.",
    "Look at how men have transformed today. From showing their ankles and wearing fitted pants to plucking their eyebrows, manicuring their nails, and following skincare routines. They're embracing practices traditionally considered feminine.",
    "It's astonishing how men behave these days. Exposing their ankles, wearing tailored pants, grooming their eyebrows, getting manicures, and following skincare routines. They're taking up practices usually associated with women.",
    "Men have certainly changed today. With their bare ankles, slim-fit pants, groomed eyebrows, polished nails, and skincare habits, they're adopting routines traditionally seen as feminine.",
    "The bronzer in your new face palette is way too orange-toned for my skin.",
    "Why did you discontinue my holy grail brow pomade shade? I'm devastated!",
    "Your cream blush formula looks incredible at first but fades away within an hour or two.",
    "There's an insane amount of fallout every time I use your shimmery eyeshadow palettes.",
    "allergic reaction",
    "You are some tired charlatans !!!",
    "below expectations",
    "It was the only product that managed both dryness and makeup effectively, leaving a light texture on my face. My skin is quite difficult to deal with.",
    "This was the only product that addressed both dryness and makeup seamlessly, providing a light finish on my face. My skin tends to be very challenging.",
    "The product was unique in its ability to handle both dryness and makeup, leaving my face with a light texture. My skin is particularly difficult.",
    "It was the sole product that effectively managed dryness and makeup, leaving a light, pleasant texture on my face. My skin has always been problematic.",
    "This product was the only one that worked for both dryness and makeup, leaving a light feel on my face. I have particularly challenging skin.",
    "This product is absolute shit, I'm never buying it again!",
    "Your customer service is fucking useless!",
    "I'm so pissed off with the quality of this product.",
    "On my dick",
    "Why do you sell such crappy products?",
    "This is the worst experience I've had with any brand, ever.",
    "Who would afford to order?",
    "Stop ripping people off with your shitty products!",
    "Your website is a nightmare to navigate, what the hell?",
    "I'm fed up with your lack of support.",
    "This product broke after one use, what the fuck?",
    "This vegan product did not work for me.",
    "The cruelty-free makeup irritated my skin.",
    "I'm not happy with the quality of this plastic-free item.",
    "This paraben-free cream caused a breakout.",
    "The microplastic-free scrub is too harsh on my skin."
],

    "Feedback-Compliments": [
    "I love the quality of your products!",
    "The customer service was excellent.",
    "It's my favorite",
    "I just love it! ❤️",
    "I'm using the cream with yellows and I absolutely adore it! ❤️",
    "The cream with yellows is part of my routine, and I just love it! ❤️",
    "I can't get enough of the new set of lipsticks—I absolutely love them! ❤️",
    "I am very satisfied with my purchase.",
    "I admire you for your courage",
    "The packaging was beautiful and intact.",
    "I'm using the night serum and absolutely adore it!",
    "I've been using the serum and I love it!",
    "I use the night serum and I'm a big fan of it!",
    "The vitamin c cream is part of my routine, and I adore it!",
    "I can't get enough of the foaming cleanser—I absolutely love it!",
    "It's gorgeous!",
    "I love your products!",
    "The new serum is amazing!",
    "Great customer service experience!",
    "Your moisturizer is the best I've ever used.",
    "I'm very satisfied with my purchase.",
    "I haven't used Brand_D's revitalizing face serum, ultra-hydrating night cream, gentle foaming cleanser, or refreshing facial mist yet, but reading the ingredients has really piqued my curiosity!",
    "Although I haven't tried them yet, the antioxidant-rich day cream, soothing eye gel, deep-cleansing clay mask, and nourishing lip balm from Brand_D have intrigued me based on their ingredients!",
    "I haven't had the chance to use Brand_D's brightening vitamin C serum, lightweight moisturizer, exfoliating scrub, or calming toner, but the ingredients list has certainly caught my attention!",
    "While I haven't used them so far, the rejuvenating retinol cream, clarifying facial oil, hydrating sheet masks, and gentle makeup remover from Brand_D have aroused my curiosity after reading about their ingredients!",
    "I haven't tried Brand_D's hydrating essence, firming neck cream, balancing facial mist, or protective sunscreen yet, but the ingredients have really sparked my interest!",
    "The product exceeded my expectations.",
    "For me, it works perfectly."
    "It works wonders for me. I've been using it alongside a cleansing gel for several years, and it's greatly reduced my wrinkles."
    "This product has been perfect for me. Paired with a cleansing gel, it's reduced a lot of my wrinkles over the past few years."
    "For me, it has been amazing. I've been using it with a cleansing gel for years, and it has significantly faded my wrinkles. And I'm over 50! Keep experimenting with products until you discover the right one."
    "It's been perfect for me."
    "Just wanted to rave about your new Velvet Blur lippie formula - it's the most comfortable matte I've ever tried!",
    "You guys really hit it out of the park with the shade range for your recent foundation launch. So inclusive!",
    "Your cruelty-free practices and ethically-sourced ingredient philosophy is what keeps me loyal.",
    "The sleek, minimalist aesthetic of your makeup packaging and branding is just chef's kiss.",
    "My favorite products are",
    "perfect!",
    "it is just perfect",
    "the perfect choice",
    "you chose perfect",
    "Your skincare line with probiotics and superfoods is so innovative and effective. Kudos to your brand!",
    "Just wanted to rave about your metallic liquid lipstick formula - it's incredible!",
    "You guys really killed it with the shade diversity in your new concealer range.",
    "Your brand's commitment to sustainable ingredient sourcing is amazing.",
    "The sleek aesthetic and minimal font for your packaging is simply chef's kiss.",
    "Your skincare line for acne-prone skin has been a game changer!",
    "Sounds amazing",
    "Sound divine",
    "ador",
    "bravo",
    "adore",
    "adore it",
    "superb",
    "i waited for this, so excited!",
    "minunat",
    "perfect",
    "is gorgeous",
    "Big up!",
    "wonderfully",
    "This product is fucking amazing, I love it!",
    "It works perfectly for me",
    "Best customer service ever, you guys rock!",
    "I can't believe how well this works, it's fucking awesome!",
    "Your brand never disappoints, always top quality.",
    "Great quality",
    "Super quality",
    "My favorite products from Brand_C are the revitalizing face serum, the ultra-hydrating night cream, the gentle foaming cleanser, and the refreshing facial mist.",
    "From Brand_F, I love the antioxidant-rich day cream, the soothing eye gel, the deep-cleansing clay mask, and the nourishing lip balm.",
    "I can't get enough of Brand_A's brightening vitamin C serum, the lightweight moisturizer, the exfoliating scrub, and the calming toner.",
    "Brand_D's top products for me are the rejuvenating retinol cream, the clarifying facial oil, the hydrating sheet masks, and the gentle makeup remover.",
    "My skincare routine is incomplete without Brand_D's hydrating essence, the firming neck cream, the balancing facial mist, and the protective sunscreen.",
    "no routine without",
    "This is the best thing I've ever bought, hands down.",
    "Thank you for such a fantastic product, I'm a fan for life!",
    "Your products are a game-changer, holy shit!",
    "I’ve never been so happy with a purchase, great job!",
    "Keep up the amazing work, your brand is incredible!",
    "This vegan product is amazing, I love it!",
    "Best cruelty-free makeup I've ever used!",
    "I can't believe how well this plastic-free item works.",
    "This paraben-free moisturizer is fantastic.",
    "The microplastic-free scrub made my skin feel great."
],

    "Feedback-Suggestions": [
    "I have a suggestion for improving your website.",
    "It would be great if you offered more vegan products.",
    "Can you consider providing samples with orders?",
    "I suggest extending the return policy.",
    "It would be nice to have a loyalty program.",
    "A makeup setting spray would be an awesome new addition to your face product range.",
    "You should consider making your customer loyalty program more rewarding with better perks.",
    "Your fans would love to see you launch more multi-use, versatile cream products that are on-trend.",
    "It's time you extended your brow range with pomades, gels and other tools beyond just pencils.",
    "You need to tap into the huge K-beauty trends like cushion compacts, tone-up creams etc.",
    "A makeup setting spray would be an awesome addition to your existing face line.",
    "You should consider adding more value and perks to your loyalty rewards program.",
    "Launching more multi-tasking hybrid makeup sticks/creams would be so on-trend!",
    "It's time to expand your brow range with pomades, gels and other tools.",
    "You need to tap into the K-beauty cushion compact, tone-up cream trends.",
    "Can you make this product in a larger size? It's too small.",
    "It was good if",
    "It would be great if you offered more fragrance-free options.",
    "Can you add more shades for your foundation?",
    "Consider making a travel-size version of the cleanser.",
    "A larger size of the moisturizer would be appreciated.",
    "Adding a pump to the serum bottle would be convenient.",
    "I’d love to see more vegan options from your brand.",
    "Please consider using eco-friendly packaging.",
    "Can you make a fragrance-free version of this product?",
    "It would be great if you offered sample sizes for new products.",
    "Could you improve the pump on this bottle? It's hard to use.",
    "I'd love to see a more affordable version of this.",
    "Please add more colors to this lipstick range.",
    "Consider adding SPF to your moisturizers.",
    "Can you make this product available in eco-friendly packaging?",
    "I’d love to see more vegan options from your brand.",
    "Please consider using plastic-free packaging.",
    "Can you make a fragrance-free version of this vegan product?",
    "It would be great if you offered more cruelty-free skincare."
],

    "Professional Inquiry": [
    "I am interested in a partnership with your brand.",
    "Can I get information on bulk purchasing for my salon?",
    "I want to discuss a business proposal with you.",
    "Is there a professional discount for large orders?",
    "Can we arrange a meeting to discuss a collaboration?",
    "I'm a freelance makeup artist and would love to be considered for opportunities with your brand.",
    "My salon is looking to potentially start carrying your full cosmetics range. Could you provide me info?",
    "I work in beauty media and am interested in getting some products from your upcoming collection for review/coverage purposes.",
    "As a beauty blogger, I'd love the opportunity to collaborate with your brand on tutorials or other content.",
    "I'm a professional MUA and wondered if you offer any pro discounts or loyalty programs I could sign up for?",
    "I'm a freelance makeup artist and would love any opportunities to work with your brand!",
    "My salon is considering carrying your full cosmetics line. Could you provide info?",
    "As a beauty editor, I'd love products from your new collection for editorial coverage.",
    "I'm a beauty blogger interested in potentially collaborating on tutorials/content.",
    "As a pro MUA, I was wondering if you offer any pro discount or loyalty programs?",
    "collaboration with your brand",
    "Can you place me on your PR list?",
    "I am a fashion influencer and i would love to work with yout brand",
    "I'm interested in a wholesale partnership.",
    "Can you provide information on bulk orders?",
    "Do you offer professional discounts?",
    "I'm a beauty blogger interested in collaborating.",
    "Are there any opportunities for product reviewers?",
    "community of active followers",
    "Can i receive a PR box from you?",
    "I am a big fan of your products since they appeared in the country."
    "Would you be interested in a collaboration?",
    "Do you offer any bulk purchase discounts for salons?",
    "I'd like to collaborate with your brand, who should I contact?",
    "Are there any opportunities for brand ambassadors?",
    "I'm interested in becoming a distributor, what's the process?",
    "Can we arrange a meeting to discuss a potential partnership?",
    "Do you offer professional training sessions for using your products?",
    "I'm a beauty blogger interested in reviewing your products.",
    "Is there a media kit available for influencers?",
    "I'm looking to feature your brand in my store, how can we proceed?",
    "Do you offer any bulk purchase discounts for salons that use vegan products?",
    "I'd like to collaborate with your cruelty-free brand, who should I contact?",
    "Are there any opportunities for brand ambassadors focused on sustainable beauty?",
    "I'm interested in becoming a distributor for your plastic-free products, what's the process?",
    "Can we arrange a meeting to discuss a potential partnership on eco-friendly items?"
],

    "Others": [
    "The weather is nice today.",
    "I am going for a walk in the park.",
    "What are your plans for the weekend?",
    "I enjoy cooking in my free time.",
    "The movie I watched last night was very entertaining.",
    "How do you spend your holidays?",
    "I love traveling to new places around the world.",
    "My favorite sport is basketball.",
    "Do you like listening to music while working?",
    "When is your big annual sale happening this year? I need to start budgeting for it!",
    "Do you happen to know if the brand is cruelty-free and not sold in any markets that require animal testing?",
    "As a woman of color, I'd love to see your brand showcase more diversity in your campaigns and advertising.",
    "Where are your products manufactured? I'm trying to only support brands with ethical supply chains.",
    "I saw your new brand ambassadors and am so excited for the future of the company!",
    "When does your big annual sale event happen this year? I need to start budgeting!",
    "Is your brand cruelty-free and not sold where animal testing is required by law?",
    "As a WOC, I'd love to see your campaigns showcase more racial diversity.",
    "Where are your products manufactured? Looking to support ethical supply chains.",
    "I'm so excited about your brand's new celebrity ambassadors!",
    "blowjob",
    "Can I use this product if I'm pregnant?",
    "Do you offer samples?",
    "What are your business hours?",
    "Can I change my account details?",
    "Do you have a loyalty program?",
    "stupid",
    "WIN a year’s supply of our premium beauty products! Like this post, tag 3 friends, and share to enter! #Giveaway #BeautyWin #Freebies",
    "Transform your skin with our magical elixir! Order now and get 50% off your first purchase! Use code: MAGIC50 at checkout. Limited time offer! #Skincare #BeautyDeals",
    "Unleash the secret to flawless skin! Click the link in our bio to discover our top-rated beauty products and enjoy a 30% discount! #SkincareRoutine #Discounts",
    "Say goodbye to wrinkles and hello to youthful skin! Our revolutionary anti-aging serum is now available. Shop now and get a free sample with every order! #AntiAging #BeautyTips",
    "Flash Sale Alert! Get your favorite beauty products at up to 70% off. Hurry, while stocks last! #FlashSale #BeautyBargains",
    "Exclusive offer for our followers! Buy one, get one free on selected items. Shop now and save! #BOGO #CosmeticsDeals",
    "Discover the ultimate skincare routine with our new collection. Follow the link and get 20% off your first order. #Skincare #BeautySavings",
    "Get a flawless complexion with our best-selling foundation. Limited time only, buy now and get a free brush! #MakeupDeals #BeautyEssentials",
    "Join our loyalty program and earn points with every purchase. Redeem points for exclusive discounts and free products! #LoyaltyRewards #BeautyProgram",
    "New product launch! Check out our latest range of organic skincare products. Order today and get free shipping on all orders. #NewArrivals #OrganicBeauty",
    "WIN a year’s supply of our premium beauty products! Like this post, tag 3 friends, and share to enter! #Giveaway #BeautyWin #Freebies",
    "Transform your skin with our magical elixir! Order now and get 50% off your first purchase! Use code: MAGIC50 at checkout. Limited time offer! #Skincare #BeautyDeals",
    "Unleash the secret to flawless skin! Click the link in our bio to discover our top-rated beauty products and enjoy a 30% discount! #SkincareRoutine #Discounts",
    "Say goodbye to wrinkles and hello to youthful skin! Our revolutionary anti-aging serum is now available. Shop now and get a free sample with every order! #AntiAging #BeautyTips",
    "Flash Sale Alert! Get your favorite beauty products at up to 70% off. Hurry, while stocks last! #FlashSale #BeautyBargains",
    "Exclusive offer for our followers! Buy one, get one free on selected items. Shop now and save! #BOGO #CosmeticsDeals",
    "Discover the ultimate skincare routine with our new collection. Follow the link and get 20% off your first order. #Skincare #BeautySavings",
    "Get a flawless complexion with our best-selling foundation. Limited time only, buy now and get a free brush! #MakeupDeals #BeautyEssentials",
    "Join our loyalty program and earn points with every purchase. Redeem points for exclusive discounts and free products! #LoyaltyRewards #BeautyProgram",
    "New product launch! Check out our latest range of organic skincare products. Order today and get free shipping on all orders. #NewArrivals #OrganicBeauty",
    "Special offer: Get glowing skin in just 7 days with our Vitamin C serum. Buy now and receive a 15% discount. Use code GLOW15 at checkout. #Skincare #BeautyOffer",
    "Don't miss out on our biggest sale of the year! All beauty products up to 60% off. Shop now and save big. #BeautySale #CosmeticsDeals",
    "Experience the magic of our new hydrating mask. Order now and get a free travel-size cleanser with your purchase. #SkincareMagic #FreeGift",
    "Revitalize your skin with our collagen-boosting cream. Shop today and enjoy a complimentary beauty consultation. #AntiAging #FreeConsultation",
    "Limited time only: Get our entire lip care collection for just $29.99. Click the link to shop now. #LipCare #BeautyBundle",
    "Discover the secret to perfect brows with our new eyebrow kit. Buy now and get a 20% discount. #BeautySecret #BrowsOnFleek",
    "Treat yourself to luxury with our exclusive beauty box subscription. Subscribe today and get your first box free. #BeautyBox #SubscriptionOffer",
    "Unlock the power of nature with our organic skincare range. Order now and receive a free eco-friendly tote bag. #OrganicBeauty #EcoFriendly",
    "Upgrade your beauty routine with our new line of cruelty-free cosmetics. Shop now and take 10% off your first order. #CrueltyFree #BeautyRoutine",
    "Back in stock: Our fan-favorite moisturizer. Hurry, quantities are limited. #BackInStock #SkincareEssentials",
    "Looking for the perfect gift? Check out our beauty gift sets. Buy one, get one 50% off. #GiftSets #BeautyGifts",
    "Say hello to clear skin with our acne-fighting products. Order today and get a free consultation with our skincare expert. #ClearSkin #FreeConsultation",
    "Exclusive online offer: Get a free lip balm with any purchase over $50. Shop now and pamper your lips. #FreeGift #LipCare",
    "Achieve a flawless finish with our new foundation range. Buy one, get one free on all shades. #Foundation #BOGO",
    "Pamper yourself with our luxurious spa collection. Get 25% off when you buy the complete set. #SpaCollection #BeautySavings",
    "New customer special: Enjoy 20% off your first order when you sign up for our newsletter. #NewCustomer #DiscountOffer",
    "Get salon-quality hair at home with our new haircare line. Order now and receive a free hairbrush. #Haircare #FreeGift",
    "Join our VIP club and get exclusive access to new products, special discounts, and more. Sign up today! #VIPClub #ExclusiveAccess",
    "Free shipping on all orders over $75. Shop now and save on your favorite beauty products. #FreeShipping #BeautySavings",
    "Limited edition alert: Our new eyeshadow palette is here. Shop now before it's gone. #LimitedEdition #EyeshadowPalette",
     "https://",
    "Can you explain why this product is better than the competitors?",
    "Why did you discontinue my favorite product? This sucks!",
    "Do you have a store locator on your website?",
    "What’s the difference between these two products?",
    "Can you recommend a product for my specific skin type?",
    "I need advice on a skincare routine, can you help?",
    "Why are your products so highly rated? What's the secret?",
    "Can someone help me choose the right shade for my skin?",
    "What do your customers say about this product?",
    "Fuck this, I'm done!",
    "This shit is unbelievable.",
    "Damn, that was close!",
    "What the hell is going on?",
    "He's such a bastard.",
    "She's acting like a bitch.",
    "This is a load of crap.",
    "Stop being such a dick.",
    "Don't be an asshole.",
    "I need to take a piss.",
    "He's a total prick.",
    "Don't be a douchebag.",
    "Quit acting like a jackass.",
    "This is complete bullshit.",
    "He's got a huge cock.",
    "That motherfucker cut me off in traffic.",
    "She called him a cunt.",
    "Screw you and your ideas.",
    "He's such a twat.",
    "That's bloody fantastic!",
    "Can you explain why your products are better for the environment?",
    "Why did you discontinue my favorite cruelty-free product?",
    "Do you have a store locator on your website for eco-friendly products?",
    "What’s the difference between your vegan and regular product lines?",
    "Can someone help me choose the right shade for my skin in your cruelty-free range?"
    ]
}

# Generate augmented texts for each category
augmented_data = {}

for category, base_texts in categories.items():
    augmented_texts = []
    for text in base_texts:
        augmented_texts.extend(augment_text(text))
    augmented_data[category] = augmented_texts

# Generate synthetic data for each category
all_data = []

for category, texts in augmented_data.items():
    synthetic_data = generate_unique_synthetic_data(texts, category, num_unique_samples_per_category)
    all_data.extend(synthetic_data)

# Shuffle all data
random.shuffle(all_data)

# Convert to DataFrame
df = pd.DataFrame(all_data)

# Save to CSV
df.to_csv('intent-data2.csv', index=False)

print("Saved with improvements")
# Out:
# C:\Users\crist\anaconda3\Lib\site-packages\transformers\utils\generic.py:260: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   torch.utils._pytree._register_pytree_node(
# Saved with improvements
